# %%
a=10
b=20
c=30
d=40
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 30
# -20
# 300
# 2.0
# 2
# 0

# %%
a=150
b=155
c=160
d=165
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 305
# -10
# 24000
# 1.0333333333333334
# 1
# 10

# %%
a=25
a-=50
print(a)
# Out:
# -25

# %%
b=15
b*=25
print(b)
# Out:
# 375

# %%
c=100
c/=15
print(c)
# Out:
# 6.666666666666667

# %%
#comparision operators- >,<,>=,<=,==,!= (return true or false)
a=5
b=10
c=10
d=20
print(a>b)
print(b<c)
print(b>=c)
print(b==c)
print(b!=d)
# Out:
# False
# False
# True
# True
# True

# %%
# logical operators - and,or,not,
# and - this operators checking all conditions are true result is true rest case failed 
# or - this oiperators check either one conditions true true then result true rest cases failed 
a=10
b=20
c=20
d=60
print(a>b and b==c)
print(a<b and c<d)
print(a>b or b==c)
print(a>b and b!=c)
print (not a>b or b!=c)
# Out:
# False
# True
# True
# False
# True

# %%
# membership operators - checking members are present in that sequence or collection - in , not in
names=["shiva","vikas","divya","alok"]
print("alok" in names)
print("chandra" in names)
print("shiva" not in names)
print("vikas" in names)
# Out:
# True
# False
# False
# True

# %%
# identity operators - memory identification of values - is , is not 
a=10000
b=10000
print(id(a))
print(id(a))
print(a is b)
# Out:
# 1932325591280
# 1932325591280
# False

# %%
a=10
b=10
print(id(a))
print(id(b))
print (a is b)
# Out:
# 140719340745928
# 140719340745928
# True
